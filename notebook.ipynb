# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1

# %% [markdown]
# For every column in the data:
#
# a. State whether the values match the description given in the table above. <br>
# b. State the number of missing values in the column. <br>
# c. Describe what you did to make values match the description if they did not
# match.

# %% [markdown]
# ### *Solution*
#
# - **claim_id**
#     - The column values is match with the description given (there are 2000 unique values)
#     - no missing values
#     - no changes were made to this column
# - **time_to_close**
#     - The column values is match with the description given (there are  256 unique values)
#     - no missing values
#     - no changes were made to this column
# - **claim_amount**
#     - The column values is match with the description given (range from R$ 1637.94 to 76106.8) except the data type is not a float
#     - no missing values
#     - I remove the currency and convert the column into numerical data type
# - **amount_paid**
#     - The column values is match with the description given (range from 1516.72 to 52498.75)
#     - There are 36 missing values
#     - The missing values was filled with median values (~20105.70)
# - **location**
#     - The column values is match with the description given (4 unique locations)
#     - no missing values
#     - no changes were made to this column
# - **individuals_on_claim**
#     - The column values is match with the description given (with range 1 - 15)
#     - no missing values
#     - no changes were made to this column
# - **linked_cases**
#     - The column values is match with the description given
#     - There are 26 missing values
#     - The missing values were replaced with False
# - **cause**
#     - The column values is match with the description given (“vegetable”, “meat”
# or “unknown”).
#     - no missing values
#     - There is some change I did to standardize the case since it is inconsistent in the case format

# %% [markdown]
# ## Task 2

# %% [markdown]
# Create a visualization that shows the number of claims in each location. Use the
# visualization to:<br>
#
# a. State which category of the variable location has the most observations <br>
# b. Explain whether the observations are balanced across categories of the
# variable location

# %% [markdown]
# ### *Solution* <br>
#
# - Location that has most observations is **Recife**
# ![Task_2](Task_2.png)
#
# - From the visualization, we could tell that the observation *does not have a balance* among the locations. The picture tells us we have Recife in the first position followed by Fortaleza, Sao Luis and the last is Natal.

# %% [markdown]
# ## Task 3

# %% [markdown]
# Describe the distribution of time to close for all claims. Your answer must include a
# visualization that shows the distribution.

# %% [markdown]
# ### *Solution* <br>
#
# As the Vivendo's legal team is considering the time to close of the claims will be important in this case. We should look the data distribution first.
#
# ![Task_3](Task_3.png)
#
# The picture shows that we have data that is not normally distributed and is more likely right-skewed. Most of the cases closed takes around 150 - 210 days (~5-7 months). Even though there is a possibility that the case takes more than 250 to manage. For some insight, there might be special cases that cause the problem to solve need more time than others therefore the legal team could identify and make some classification for certain uncommon cases that take more than 6 month.

# %% [markdown]
# ## Task 4

# %% [markdown]
# Describe the relationship between time to close and location. Your answer must
# include a visualization to demonstrate the relationship.

# %% [markdown]
# ### *Solution* <br>
#
# In this visualization below we will see how is the relation distribution between time to close and the location.
#
# ![Task_4-1](Task_4-1.png)

# %% [markdown]
# At a glance, we can see that the dataset we have it shows that all locations have outlier data on the time to close value. Among those locations, we notice that the data spread is slightly similar between the areas. Lets have a better look below,
#
# ![Task_4-2](Task_4-2.png)

# %% [markdown]
# From the boxplot above we could say that:
# - Recife has,
#     - lower whisker is 90 days
#     - lower hinge (25th percentile) is 157
#     - median is 178 days
#     - upper hinge (75th percentile) is 203
#     - Upper whisker is 271
# - Fortaleza has,
#     - lower whisker is 88 days
#     - lower hinge (25th percentile) is 157
#     - median is 180 days
#     - upper hinge (75th percentile) is 205
#     - Upper whisker is 274
# - Sao Luis has,
#     - lower whisker is 98 days
#     - lower hinge (25th percentile) is 161
#     - median is 179 days
#     - upper hinge (75th percentile) is 205
#     - Upper whisker is 268
# - Natal has,
#     - lower whisker is 93 days
#     - lower hinge (25th percentile) is 157
#     - median is 179 days
#     - upper hinge (75th percentile) is 205
#     - Upper whisker is 277

# %% [markdown]
# Based on this information, we can draw the following insights:
#
# - Variability: Fortaleza and Natal have the largest IQRs, indicating higher variability in handling times compared to Recife and Sao Luis.
#
# - Outliers: All cities have outliers, suggesting that there are orders with exceptionally long handling times.
#
# - Median Comparison: The medians for all cities are similar, ranging from 178 to 180 days. This indicates that, on average, it takes around this time to handle claims in these cities.
#
# - Performance Comparison: Recife and Sao Luis have relatively smaller IQRs compared to Fortaleza and Natal, suggesting more consistency in handling times within the interquartile range.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
